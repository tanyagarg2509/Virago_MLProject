# %%
import pandas as pd
from joblib import load

# %%
text = ["Black lives matter ass kits from 2016 IPL match to raise funds"]

# %%
pipeline = load("text_classification.joblib")

# %%
pipeline.predict(text)
# Out:
# array([0], dtype=int64)
