# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('Harassment Lexicon.csv')

# %%
data = df['Racial']
keywords = data[35:168]
dk = keywords[-keywords.isnull()]
dk.size
dk.shape

# dk.to_csv('keywords.csv')
# Out:
# filipino
# 35       filipino
# 36            Fok
# 37           frog
# 38          gipsy
# 39           gook
#           ...
# 156        Yankee
# 157     yellowman
# 158           yid
# 159        zigabo
# 160    zipperhead
# Name: Racial, Length: 126, dtype: object

# %%
import tweepy

consumer_key = 'IJBXd9Lxnwmdvtz3VqDyD2DHQ'
consumer_secret = 'xGOwKsJxSbWZqcjR9cMAMuT59IiIrbfZ8gUWEnyG8Yqg7ZplzG'
access_key = '1176413002599288832-yyjhFa386RpMJPkldvYQjviWTneYC4'
access_secret = 'GfWOaYcTmhOYR1VT5LCTwB4Dfgr5Dd5CaP58x2y7fxAnz'
                   
auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_key, access_secret)
api = tweepy.API(auth, wait_on_rate_limit=True, wait_on_rate_limit_notify=True)

# %%
# result = []
# for i in dk[0:2]:
#     search_results = api.search(q=i, count=20,lang="en")
#     print(search_results[0])

# #     for item in search_results:
# #     print(search_results[0]._json)
#     print(search_results[0]._json.keys())
# #         result.append(item._json)
# #         print(result)
# Out:
# Status(_api=<tweepy.api.API object at 0x00000224DD8B2BC8>, _json={'created_at': 'Tue Jul 21 14:25:55 +0000 2020', 'id': 1285581778028134408, 'id_str': '1285581778028134408', 'text': 'RT @Jeff__Benjamin: Here we go! \n\nAfter breaking out big time on the @Billboard Social 50 chart, Filipino boy band @SB19Official will relea…', 'truncated': False, 'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [{'screen_name': 'Jeff__Benjamin', 'name': 'Jeff Benjamin', 'id': 21621886, 'id_str': '21621886', 'indices': [3, 18]}, {'screen_name': 'billboard', 'name': 'billboard', 'id': 9695312, 'id_str': '9695312', 'indices': [69, 79]}, {'screen_name': 'SB19Official', 'name': 'SB19 Official', 'id': 1006064993282842624, 'id_str': '1006064993282842624', 'indices': [115, 128]}], 'urls': []}, 'metadata': {'iso_language_code': 'en', 'result_type': 'recent'}, 'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 1267270590634713088, 'id_str': '1267270590634713088', 'name': 'Lyssa Loves SB19💄❤', 'screen_name': 'Yssa_Carlem', 'location': '', 'description': 'HUBBYKEN😍', 'url': None, 'entities': {'description': {'urls': []}}, 'protected': False, 'followers_count': 491, 'friends_count': 512, 'listed_count': 0, 'created_at': 'Mon Jun 01 01:44:10 +0000 2020', 'favourites_count': 10527, 'utc_offset': None, 'time_zone': None, 'geo_enabled': False, 'verified': False, 'statuses_count': 21362, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'is_translation_enabled': False, 'profile_background_color': 'F5F8FA', 'profile_background_image_url': None, 'profile_background_image_url_https': None, 'profile_background_tile': False, 'profile_image_url': 'http://pbs.twimg.com/profile_images/1281147957534879745/MEUFvtnx_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1281147957534879745/MEUFvtnx_normal.jpg', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1267270590634713088/1594284450', 'profile_link_color': '1DA1F2', 'profile_sidebar_border_color': 'C0DEED', 'profile_sidebar_fill_color': 'DDEEF6', 'profile_text_color': '333333', 'profile_use_background_image': True, 'has_extended_profile': False, 'default_profile': True, 'default_profile_image': False, 'following': False, 'follow_request_sent': False, 'notifications': False, 'translator_type': 'none'}, 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'retweeted_status': {'created_at': 'Tue Jul 21 12:56:53 +0000 2020', 'id': 1285559372664524801, 'id_str': '1285559372664524801', 'text': 'Here we go! \n\nAfter breaking out big time on the @Billboard Social 50 chart, Filipino boy band @SB19Official will r… https://t.co/YYnEAd0NC7', 'truncated': True, 'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [{'screen_name': 'billboard', 'name': 'billboard', 'id': 9695312, 'id_str': '9695312', 'indices': [49, 59]}, {'screen_name': 'SB19Official', 'name': 'SB19 Official', 'id': 1006064993282842624, 'id_str': '1006064993282842624', 'indices': [95, 108]}], 'urls': [{'url': 'https://t.co/YYnEAd0NC7', 'expanded_url': 'https://twitter.com/i/web/status/1285559372664524801', 'display_url': 'twitter.com/i/web/status/1…', 'indices': [117, 140]}]}, 'metadata': {'iso_language_code': 'en', 'result_type': 'recent'}, 'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 21621886, 'id_str': '21621886', 'name': 'Jeff Benjamin', 'screen_name': 'Jeff__Benjamin', 'location': 'New York, NY', 'description': 'K-Pop Columnist @Billboard|Editor @TIDAL|Correspondent @KBSWorldWeKPop|Words @NYTimes @RollingStone @TeenVogue @GQm ...
# Status(_api=<tweepy.api.API object at 0x00000224DD8B2BC8>, _json={'created_at': 'Tue Jul 21 14:24:13 +0000 2020', 'id': 1285581350335111168, 'id_str': '1285581350335111168', 'text': 'Yoh please don’t lie to me 😭😭 \nI’m actually an understanding person but when you lie you taking me for a poes. \n\nYe… https://t.co/nIWHTweTUR', 'truncated': True, 'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [], 'urls': [{'url': 'https://t.co/nIWHTweTUR', 'expanded_url': 'https://twitter.com/i/web/status/1285581350335111168', 'display_url': 'twitter.com/i/web/status/1…', 'indices': [117, 140]}]}, 'metadata': {'iso_language_code': 'en', 'result_type': 'recent'}, 'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 1279635354, 'id_str': '1279635354', 'name': 'The Caged Avo', 'screen_name': 'munzhe_', 'location': 'Pretoria, South Africa', 'description': 'Co-Owner of SwiftDelivery Store🛍| Student \U0001fa7a | Lover of Life♥️', 'url': 'https://t.co/bTcyZoFvdx', 'entities': {'url': {'urls': [{'url': 'https://t.co/bTcyZoFvdx', 'expanded_url': 'https://swiftdelivery.co.za/', 'display_url': 'swiftdelivery.co.za', 'indices': [0, 23]}]}, 'description': {'urls': []}}, 'protected': False, 'followers_count': 2966, 'friends_count': 1950, 'listed_count': 1, 'created_at': 'Tue Mar 19 06:02:26 +0000 2013', 'favourites_count': 29804, 'utc_offset': None, 'time_zone': None, 'geo_enabled': True, 'verified': False, 'statuses_count': 12502, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'is_translation_enabled': False, 'profile_background_color': '9266CC', 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme11/bg.gif', 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme11/bg.gif', 'profile_background_tile': True, 'profile_image_url': 'http://pbs.twimg.com/profile_images/1247661898956447750/53EMxuNO_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1247661898956447750/53EMxuNO_normal.jpg', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1279635354/1593096409', 'profile_link_color': 'F5ABB5', 'profile_sidebar_border_color': '000000', 'profile_sidebar_fill_color': 'DDEEF6', 'profile_text_color': '333333', 'profile_use_background_image': True, 'has_extended_profile': True, 'default_profile': False, 'default_profile_image': False, 'following': False, 'follow_request_sent': False, 'notifications': False, 'translator_type': 'none'}, 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'is_quote_status': False, 'retweet_count': 0, 'favorite_count': 0, 'favorited': False, 'retweeted': False, 'lang': 'en'}, created_at=datetime.datetime(2020, 7, 21, 14, 24, 13), id=1285581350335111168, id_str='1285581350335111168', text='Yoh please don’t lie to me 😭😭 \nI’m actually an understanding person but when you lie you taking me for a poes. \n\nYe… https://t.co/nIWHTweTUR', truncated=True, entities={'hashtags': [], 'symbols': [], 'user_mentions': [], 'urls': [{'url': 'https://t.co/nIWHTweTUR', 'expanded_url': 'https://twitter.com/i/web/status/1285581350335111168', 'display_url': 'twitter.com/i/web/status/1…', 'indices': [117, 140]}]}, metadata={'iso_language_code': 'en', 'result_type': 'recent'}, source='Twitter for iPhone', source_url='http://twitter.com/download/iphone', in_reply_to_status_id=None, in_reply_to_status_id_str=None, in_reply_to_user_id=None, in_reply_to_user_id_str=None, in_reply_to_screen_name=None, author=User(_api=<tweepy.api.API object at 0x00000224DD8B2BC8>, _json={'id': 1279635354, 'id_str': '1279635354', 'name': 'The Caged Avo', 'screen_name': 'munzhe_', 'location': 'Pretoria, South Africa', 'description': 'Co-Owner of SwiftDelivery Store🛍| Student \U0001fa7a | Lover of Life♥️', 'url': 'https://t.co/bTcyZoFv ...
