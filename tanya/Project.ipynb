# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('Harassment Lexicon.csv')

# %%
data = df['Racial']
keywords = data[35:168]
dk = keywords[-keywords.isnull()]
dk.size
dk.shape

# dk.to_csv('keywords.csv')
# Out:
# filipino
# 35       filipino
# 36            Fok
# 37           frog
# 38          gipsy
# 39           gook
#           ...
# 156        Yankee
# 157     yellowman
# 158           yid
# 159        zigabo
# 160    zipperhead
# Name: Racial, Length: 126, dtype: object

# %%
import tweepy

consumer_key = 'IJBXd9Lxnwmdvtz3VqDyD2DHQ'
consumer_secret = 'xGOwKsJxSbWZqcjR9cMAMuT59IiIrbfZ8gUWEnyG8Yqg7ZplzG'
access_key = '1176413002599288832-yyjhFa386RpMJPkldvYQjviWTneYC4'
access_secret = 'GfWOaYcTmhOYR1VT5LCTwB4Dfgr5Dd5CaP58x2y7fxAnz'
                   
auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_key, access_secret)
api = tweepy.API(auth, wait_on_rate_limit=True, wait_on_rate_limit_notify=True)

# %%
# result = []
# for i in dk[0:2]:
#     search_results = api.search(q=i, count=20,lang="en")
#     print(search_results[0])

# #     for item in search_results:
# #     print(search_results[0]._json)
#     print(search_results[0]._json.keys())
# #         result.append(item._json)
# #         print(result)
dk[0:2]
# Out:
# 35    filipino
# 36         Fok
# Name: Racial, dtype: object

# %%
search_results = api.search(q='filipino', count=20,lang="en")
# print(search_results[0]._json)
data = pd.DataFrame(search_results[0]._json)
data
# Out:
#                                         created_at                   id  \
# hashtags            Tue Jul 21 17:31:30 +0000 2020  1285628479657172999
# symbols             Tue Jul 21 17:31:30 +0000 2020  1285628479657172999
# user_mentions       Tue Jul 21 17:31:30 +0000 2020  1285628479657172999
# urls                Tue Jul 21 17:31:30 +0000 2020  1285628479657172999
# iso_language_code   Tue Jul 21 17:31:30 +0000 2020  1285628479657172999
# ...                                            ...                  ...
# retweet_count       Tue Jul 21 17:31:30 +0000 2020  1285628479657172999
# favorite_count      Tue Jul 21 17:31:30 +0000 2020  1285628479657172999
# favorited           Tue Jul 21 17:31:30 +0000 2020  1285628479657172999
# retweeted           Tue Jul 21 17:31:30 +0000 2020  1285628479657172999
# possibly_sensitive  Tue Jul 21 17:31:30 +0000 2020  1285628479657172999
#
#                                  id_str  \
# hashtags            1285628479657172999
# ...
